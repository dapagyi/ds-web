# %% [markdown]
# # DS-HW-01
#
# Klaszterezés (MNIST digits)
#
# **Honlap:** <a href="https://apagyidavid.web.elte.hu/2025-2026-2/ds"
# target="_blank">apagyidavid.web.elte.hu/2025-2026-2/ds</a>
#
# <a target="_blank" href="https://colab.research.google.com/github/dapagyi/ds-web/blob/notebooks/ds-hw-01.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# # Klaszterezés
#
# *Próbálj ki minél többféle klaszterező algoritmust az MNIST digits
# adathalmazon!*
#
# - Találj ki legalább kétféle mérőszámot, amellyel a kapott
#   klaszterezéseid minőségét tudod jellemezni.
# - Melyik klaszterező eljárás és milyen paraméterválasztással a leginkább
#   alkalmas a probléma megoldására?
#
# **Határidő:** 2026. 04. 09. 23:59

# %%
from sklearn.datasets import load_digits
import matplotlib.pyplot as plt

digits = load_digits()

print(f"Shape of dataset: {digits.data.shape}")

_, axes = plt.subplots(nrows=1, ncols=4, figsize=(10, 3))
for ax, image, label in zip(axes, digits.images, digits.target):
    ax.set_axis_off()
    ax.imshow(image, cmap=plt.cm.gray, interpolation="nearest")
    ax.set_title("Training: %i" % label)
# Out:
# Shape of dataset: (1797, 64)

# %%
# TODO
# digits
