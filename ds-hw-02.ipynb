# %% [markdown]
# # DS-HW-02
#
# MapReduce
#
# **Web page:** <a href="https://apagyidavid.web.elte.hu/2025-2026-2/ds"
# target="_blank">apagyidavid.web.elte.hu/2025-2026-2/ds</a>
#
# <a target="_blank" href="https://colab.research.google.com/github/dapagyi/ds-web/blob/notebooks/ds-hw-02.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# # MapReduce Homework
#
# Come up with a simple example and a dataset similar to the examples that
# I showed (i.e. word count, average scores, etc) and manually define the
# map function, reduce function, and generate the output as in the two
# examples I showed.
#
# Then set up a PySpark environment as in the notebook and generate the
# same results using PySpark.
#
# **Deadline:** 2026. 04. 23. 23:59

# %%
# TODO
