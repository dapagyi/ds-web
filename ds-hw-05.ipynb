# %% [markdown]
# # DS-HW-05
#
# Streaming Algorithms
#
# **Web page:** <a href="https://apagyidavid.web.elte.hu/2025-2026-2/ds"
# target="_blank">apagyidavid.web.elte.hu/2025-2026-2/ds</a>
#
# <a target="_blank" href="https://colab.research.google.com/github/dapagyi/ds-web/blob/notebooks/ds-hw-05.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# # Streaming Algorithms Homework
#
# Generate your own small toy example of a “streaming dataset” containing
# about 100 elements with repeats (similar to the small examples in this
# script, but a little bigger).
#
# 1.  Calculate (a) the number of distinct elements and (b) the second
#     moment of your toy dataset for comparison.
# 2.  Run the python-implementation of Flajolet-Martin on your datastream
#     and experiment with the number of hash-functions used. What do you
#     notice about the relationship between the error and the number of
#     hash-functions? What might explain this behavior (keep in mind that
#     this is a small example)?
# 3.  Run the PySpark implementation of `ApproxCountDistinct()` on your
#     data stream and experiment with different rsd threshholds; compare
#     to Flajolet-Martin (simple qualitative comparison is fine!)
# 4.  Run the AMS second moment python implementation on your datastream,
#     and experiment with different numbers of estimators. In particular,
#     take a fairly fine mesh over number of estimators ranging from 1 to
#     1000 and plot error vs number of estimators (it may be useful to
#     average over multiple trials to get a better error estimate).
#     - Does the data follow the $1/\varepsilon^2$ pattern that we expect?
#     - If not, why might this be explained by the fact that we have a
#       very small datastream?

# %% [raw]
# <!-- __Deadline:__ TBD -->

# %%
# TODO
